# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
import pandas as pd

df = pd.read_csv("../data/raw/retail_data.csv")
df.head()
# Out:
#    customer_id  sales  quantity  frequency  recency  inventory  churn
# 0            1   2500         5         12       30        100      0
# 1            2   1200         2          4      120         45      1
# 2            3   4300         8         20       10        180      0
# 3            4    800         1          2      250         20      1
# 4            5   3100         6         15       45         90      0

# %%
X = df[["sales", "quantity", "frequency", "recency", "inventory"]]
y = df["churn"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
model = XGBClassifier(
    n_estimators=150,
    learning_rate=0.05,
    max_depth=4,
    random_state=42,
    eval_metric="logloss"
)

model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = XGBClassifier(
#       2     n_estimators=150,
#       3     learning_rate=0.05,
#       4     max_depth=4,
#
# NameError: name 'XGBClassifier' is not defined

# %%
predictions = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))

# %%
df["churn_risk"] = model.predict_proba(X)[:, 1]
df.to_csv("../data/processed/churn_prediction.csv", index=False)
